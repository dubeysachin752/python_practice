# %%
lst = ["Geeks", "For", "love"]

# %%
for var in lst:
    print (lst.index(var),var)
# Out:
# 0 Geeks
# 1 For
# 2 love

# %%
lst[-1]
# Out:
# 'love'

# %%
lst[-1::]
# Out:
# ['love']

# %%
a= [i for i in range(10) if i % 3 == 0]

# %%
a
# Out:
# [0, 3, 6, 9]

# %%
metrix= [[j for j in range(3)] for i in range(3)]

# %%
metrix
# Out:
# [[0, 1, 2], [0, 1, 2], [0, 1, 2]]

# %%
a =[lambda arg=x: arg * 10 for x in range(1, 5)]
print(a)
# Out:
# [<function <listcomp>.<lambda> at 0x000001F64DE70670>, <function <listcomp>.<lambda> at 0x000001F64DE70CA0>, <function <listcomp>.<lambda> at 0x000001F64DE70AF0>, <function <listcomp>.<lambda> at 0x000001F64DE70D30>]

# %%
for i in xrange(10):    # numbers from o to 9
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-bd32a9c8a731> in <module>
# ----> 1 for i in xrange(10):    # numbers from o to 9
#       2     print(i)
#
# NameError: name 'xrange' is not defined

# %%
def recursive_fibonacci(n):
    if n <= 1:
        return n
    else:
        return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
    n_terms = 10
 
# check if the number of terms is valid
    if n_terms <= 0:
      print("Invalid input ! Please input a positive value")
    else:
      print("Fibonacci series:")
    for i in range(n_terms):
        print(recursive_fibonacci(i))

# %%
a=recursive_fibonacci(80)
a
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-afd273ab740a> in <module>
# ----> 1 a=recursive_fibonacci(80)
#       2 a
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# <ipython-input-74-18394ce5bde5> in recursive_fibonacci(n)
#       3         return n
#       4     else:
# ----> 5         return(recursive_fibonacci(n-1) + recursive_fibonacci(n-2))
#       6     n_terms = 10
#       7
#
# KeyboardInterrupt:

# %%
# Out:
# 45
